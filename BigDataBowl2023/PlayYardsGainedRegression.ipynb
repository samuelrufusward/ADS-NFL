# %%
import pandas as pd
import numpy as np

# %%
player_stats = pd.read_csv("merged_df.csv").drop('Unnamed: 0', axis='columns')

# %%
play_data = pd.read_csv("./data2023/plays.csv")

# %%
player_stats.head()
# Out:
#    Acceleration  Age  Agility        Archetype  Awareness  BC Vision  \
# 0            66   44       70  QB_FieldGeneral         99         51
# 1            77   39       67  QB_FieldGeneral         85         68
# 2            84   37       81    QB_Improviser         96         78
# 3            79   38       71  QB_FieldGeneral         82         73
# 4            80   37       72      TE_Blocking         76         75
#
#    Block Shedding  Break Sack  Break Tackle  Carrying  ...  Zone Coverage  \
# 0              33          61            31        69  ...             19
# 1              45          83            64        60  ...             13
# 2              19          86            65        63  ...             19
# 3              12          82            66        63  ...             12
# 4              45          11            54        78  ...             13
#
#     birthDate  collegeName         displayName  height  nflId  \
# 0  1977-08-03     Michigan           Tom Brady     6-4  25511
# 1  1982-03-02    Miami, O.  Ben Roethlisberger     6-5  28963
# 2  1983-12-02   California       Aaron Rodgers     6-2  29851
# 3  1982-11-24      Harvard    Ryan Fitzpatrick     6-2  30078
# 4  1984-05-19         UCLA      Marcedes Lewis     6-6  30842
#
#   officialPosition         updatedName        updatedName2  weight
# 0               QB           Tom Brady           Tom Brady     225
# 1               QB  Ben Roethlisberger  Ben Roethlisberger     240
# 2               QB       Aaron Rodgers       Aaron Rodgers     225
# 3               QB    Ryan Fitzpatrick    Ryan Fitzpatrick     228
# 4               TE      Marcedes Lewis      Marcedes Lewis     267
#
# [5 rows x 84 columns]

# %%
player_stats.Team.unique()
# Out:
# array(['Buccaneers', 'Steelers', 'Packers', 'Football Team', 'Rams',
#        'Falcons', 'Seahawks', 'Ravens', 'Saints', '49ers', 'Chargers',
#        'Dolphins', 'Eagles', 'Broncos', 'Patriots', 'Bills', 'Titans',
#        'Texans', 'Bears', 'Cowboys', 'Cardinals', 'Vikings', 'Giants',
#        'Browns', 'Lions', 'Bengals', 'Raiders', 'Colts', 'Jaguars',
#        'Panthers', 'Chiefs', 'Jets'], dtype=object)

# %%
# Get name to match play_data format
player_stats["abrev_name"] = player_stats.displayName.apply(lambda x: str(x)[0]+ "."+"".join(str(x).split(" ")[1:]))
player_stats.abrev_name = player_stats.abrev_name.apply(lambda x: str(x).lower())

# %%
player_stats.abrev_name
# Out:
# 0                t.brady
# 1       b.roethlisberger
# 2              a.rodgers
# 3          r.fitzpatrick
# 4                m.lewis
#               ...
# 1409         j.jefferson
# 1410             d.milne
# 1411            g.stuard
# 1412            j.jacobs
# 1413            j.heflin
# Name: abrev_name, Length: 1414, dtype: object

# %%
team_mapping = {"PHI": "Eagles", "BUF": "Bills", "ATL": "Falcons", "PIT": "Steelers", "CLE": "Browns", "CIN": "Bengals", "IND": "Colts", "TEN": "Titans", "MIA": "Dolphins", "BAL": "Ravens", "NE": "Patriots", "HOU": "Texans", "JAX": "Jaguars", "NYG": "Giants", "NO": "Saints", "TB": "Buccaneers", "WAS": "Commanders", "ARI": "Cardinals", "CAR": "Panthers", "DAL": "Cowboys", "GB": "Packers", "CHI": "Bears", "NYJ": "Jets", "DET": "Lions", "OAK": "Raiders", "LA": "Rams", "MIN": "Vikings", "LAC": "Chargers", "KC": "Chiefs", "SF": "49ers", "DEN": "Broncos", "SEA": "Seahawks", "LV": "Raiders"}

# %%
play_data['Team'] = play_data.possessionTeam.apply(lambda x: team_mapping[str(x)])

# %%
play_data.possessionTeam.unique()
# Out:
# array(['TB', 'DAL', 'ATL', 'PHI', 'BUF', 'PIT', 'NYJ', 'CAR', 'MIN',
#        'CIN', 'DET', 'SF', 'HOU', 'JAX', 'IND', 'SEA', 'TEN', 'ARI',
#        'LAC', 'WAS', 'CLE', 'KC', 'NE', 'MIA', 'NO', 'GB', 'NYG', 'DEN',
#        'CHI', 'LA', 'LV', 'BAL'], dtype=object)

# %%
# Remove time from play description
playDescText = play_data.playDescription.apply(lambda x: " ".join(str(x).split()[1:]))
# Remove formation from play description
playDescText = playDescText.apply(lambda x: "".join(x.split(")")[1:]) if str(x).startswith("(") else x)
playDescText
# Out:
# 0         T.Brady pass incomplete deep right to C.Godwin.
# 1        D.Prescott pass deep left to A.Cooper pushed ...
# 2        D.Prescott pass short middle to D.Schultz to ...
# 3         D.Prescott pass incomplete deep left to C.Lamb.
# 4        D.Prescott pass incomplete short left to C.La...
#                               ...
# 8552     P.Mahomes sacked at NYG 16 for -8 yards (K.Cr...
# 8553     D.Jones pass short right to E.Engram pushed o...
# 8554      D.Jones sacked at NYG 20 for -8 yards (C.Jones.
# 8555     D.Jones pass incomplete short right to E.Engram.
# 8556     D.Jones sacked at NYG 14 for -6 yards (F.Clar...
# Name: playDescription, Length: 8557, dtype: object

# %%
# People who received the ball
receivers = playDescText.map(lambda x: str(x).lower().split(" ")[str(x).lower().split(" ").index("to")+1] if ("pass" in str(x).lower().split(" ") and "to" in str(x).lower().split(" ")) & ("intercept" not in str(x).lower()) else np.nan)
# Remove full stop from some names at end
receivers.loc[receivers.map(lambda x: str(x)[-1]) == "."] = receivers.loc[receivers.map(lambda x: str(x)[-1]) == "."].apply(lambda x: "".join(str(x)[:-1]))
# 2 values have NO # instead of names, so we can remove these
receivers.loc[receivers=="no"] = np.nan

# %%
play_data['abrev_name'] = receivers # column representing who received
receiver_stats = play_data.merge(player_stats, how='left', left_on=['Team','abrev_name'], right_on=['Team','abrev_name'])
receiver_stats = receiver_stats.rename(columns={'abrev_name': "receiver"})

# %%
receiver_stats.head()
# Out:
#        gameId  playId                                    playDescription  \
# 0  2021090900      97  (13:33) (Shotgun) T.Brady pass incomplete deep...
# 1  2021090900     137  (13:18) (Shotgun) D.Prescott pass deep left to...
# 2  2021090900     187  (12:23) (Shotgun) D.Prescott pass short middle...
# 3  2021090900     282  (9:56) D.Prescott pass incomplete deep left to...
# 4  2021090900     349  (9:46) (Shotgun) D.Prescott pass incomplete sh...
#
#    quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 0        1     3          2             TB           DAL           TB
# 1        1     1         10            DAL            TB          DAL
# 2        1     2          6            DAL            TB          DAL
# 3        1     1         10            DAL            TB           TB
# 4        1     3         15            DAL            TB           TB
#
#    yardlineNumber  ... Zone Coverage   birthDate  collegeName     displayName  \
# 0              33  ...          25.0  1996-02-27   Penn State    Chris Godwin
# 1               2  ...          25.0  1994-06-17      Alabama    Amari Cooper
# 2              34  ...          15.0  1996-07-11     Stanford  Dalton Schultz
# 3              39  ...          25.0  1999-04-08     Oklahoma     CeeDee Lamb
# 4              44  ...          25.0  1999-04-08     Oklahoma     CeeDee Lamb
#
#    height    nflId  officialPosition     updatedName    updatedName2 weight
# 0     6-1  44896.0                WR    Chris Godwin    Chris Godwin  209.0
# 1     6-1  42347.0                WR    Amari Cooper    Amari Cooper  211.0
# 2     6-5  46206.0                TE  Dalton Schultz  Dalton Schultz  242.0
# 3     6-2  52425.0                WR     CeeDee Lamb     CeeDee Lamb  189.0
# 4     6-2  52425.0                WR     CeeDee Lamb     CeeDee Lamb  189.0
#
# [5 rows x 117 columns]

# %%
#Drop non-Madden players and anomalies
receiver_stats.dropna(axis='rows', subset='nflId', inplace=True)
receiver_stats.reset_index(drop=True, inplace=True)

# %%
len(receiver_stats['nflId'].unique())
# Out:
# 336

# %%
feature_columns = ['Age', 'Height', 'Weight', 'Overall', 'Speed',
 'Acceleration', 'Agility', 'Change of Dir', 'Strength', 'Jumping',
 'Awareness', 'Carrying', 'Break Tackle', 'Juke Move', 'Spin Move',
 'Trucking', 'Stiff Arm', 'BC Vision', 'Catching', 'Catch In Traffic',
 'Spec Catch', 'Release', 'Short RR', 'Medium RR', 'Deep RR',
 'Throw Power', 'Throw Acc Short', 'Throw Acc Mid', 'Throw Acc Deep',
 'Throw Under Pressure', 'Throw On The Run', 'Play Action', 'Break Sack',
 'Run Block', 'Run Block Power', 'Run Block Finesse', 'Pass Block',
 'Pass Block Power', 'Pass Block Finesse', 'Impact Blocking',
 'Lead Blocking', 'Tackle', 'Hit Power', 'Pursuit', 'Man Coverage',
 'Zone Coverage', 'Press', 'Play Recognition', 'Power Moves',
 'Finesse Moves', 'Block Shedding', 'Kick Power', 'Kick Accuracy',
 'Kick Return', 'Stamina', 'Injury', 'Toughness', 'Years Pro']

# %%
yards_per_play_by_stats = pd.DataFrame({'nflId': receiver_stats['nflId'].astype('int32').unique()})

# %%
yards_per_play_by_stats['total_yards'] = yards_per_play_by_stats['nflId'].map(lambda x: receiver_stats[receiver_stats['nflId'] == x]['prePenaltyPlayResult'].sum())
yards_per_play_by_stats['play_count'] = yards_per_play_by_stats['nflId'].map(lambda x: len(receiver_stats[receiver_stats['nflId'] == x]))
yards_per_play_by_stats['yards_per_play'] = yards_per_play_by_stats['total_yards'] / yards_per_play_by_stats['play_count']

# %%
yards_per_play_by_stats = yards_per_play_by_stats.merge(player_stats[feature_columns + ['nflId']], how='inner', on='nflId')
yards_per_play_by_stats.head()
# Out:
#    nflId  total_yards  play_count  yards_per_play  Age  Height  Weight  \
# 0  44896          535          50       10.700000   25      73     205
# 1  42347          460          51        9.019608   27      73     210
# 2  46206          332          38        8.736842   25      77     244
# 3  52425          524          47       11.148936   22      74     189
# 4  41233          538          59        9.118644   28      77     231
#
#    Overall  Speed  Acceleration  ...  Power Moves  Finesse Moves  \
# 0       87     91            92  ...           10             10
# 1       92     91            89  ...           10             10
# 2       74     81            87  ...           10             10
# 3       81     90            90  ...           10             10
# 4       91     90            89  ...           10             10
#
#    Block Shedding  Kick Power  Kick Accuracy  Kick Return  Stamina  Injury  \
# 0              28          25             21           48       88      96
# 1              35          25             21           77       94      83
# 2              31          16             14           38       79      91
# 3              30          48             33           80       90      93
# 4              35          25             24           55       97      91
#
#    Toughness  Years Pro
# 0         90          4
# 1         93          6
# 2         86          3
# 3         91          1
# 4         94          7
#
# [5 rows x 62 columns]

# %%
yards_per_play_by_stats.describe()
# Out:
#               nflId  total_yards  play_count  yards_per_play         Age  \
# count    336.000000   336.000000  336.000000      336.000000  336.000000
# mean   46523.086310   145.324405   18.211310        7.339131   25.729167
# std     4763.769627   157.109522   16.712494        4.717508    2.946465
# min    30842.000000    -1.000000    1.000000       -0.500000   20.000000
# 25%    43389.500000    30.000000    4.000000        4.990741   23.000000
# 50%    46114.500000    95.500000   13.000000        7.052727   25.000000
# 75%    52429.250000   195.750000   25.250000        9.210387   28.000000
# max    53686.000000   793.000000   80.000000       50.000000   37.000000
#
#            Height      Weight     Overall       Speed  Acceleration  ...  \
# count  336.000000  336.000000  336.000000  336.000000    336.000000  ...
# mean    73.086310  217.517857   74.851190   87.315476     89.223214  ...
# std      2.991778   25.872356    8.540083    5.228098      3.125370  ...
# min     65.000000  170.000000   61.000000   62.000000     78.000000  ...
# 25%     71.000000  199.750000   68.000000   85.000000     87.750000  ...
# 50%     73.000000  212.500000   74.000000   88.000000     90.000000  ...
# 75%     76.000000  238.000000   80.000000   91.000000     91.000000  ...
# max     80.000000  320.000000   99.000000   99.000000     99.000000  ...
#
#        Power Moves  Finesse Moves  Block Shedding  Kick Power  Kick Accuracy  \
# count   336.000000     336.000000      336.000000  336.000000      336.00000
# mean     14.895833      15.500000       33.854167   21.074405       18.12500
# std      10.329115      10.639549        9.980556    7.825168        7.05855
# min       5.000000       5.000000       10.000000   11.000000       10.00000
# 25%      10.000000      10.000000       26.000000   17.750000       14.00000
# 50%      10.000000      10.000000       32.000000   20.000000       16.00000
# 75%      16.250000      17.000000       40.000000   22.000000       20.00000
# max      74.000000      66.000000       72.000000   75.000000       62.00000
#
#        Kick Return     Stamina      Injury   Toughness   Years Pro
# count   336.000000  336.000000  336.000000  336.000000  336.000000
# mean     56.202381   84.782738   87.616071   83.241071    3.559524
# std      25.196555    4.711098    3.436187    6.001361    2.763736
# min       6.000000   75.000000   75.000000   63.000000    0.000000
# 25%      35.000000   81.750000   86.000000   79.000000    1.000000
# 50%      65.000000   84.000000   88.000000   84.000000    3.000000
# 75%      78.000000   87.000000   90.000000   87.000000    5.000000
# max      98.000000   98.000000   97.000000   98.000000   15.000000
#
# [8 rows x 62 columns]

# %%
X = yards_per_play_by_stats[feature_columns].to_numpy()
X.shape
# Out:
# (336, 58)

# %%
Y = yards_per_play_by_stats['yards_per_play'].to_numpy()
Y.shape
# Out:
# (336,)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X, Y)
reg.score(X, Y)
# Out:
# 0.18408045719156307
